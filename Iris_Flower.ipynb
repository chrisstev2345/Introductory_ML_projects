# %%
# This is the Iris Flower dataset used for introductory machine learning.
# This is me trying to self-teach myself Python for data science and machine
# learning applications. I followed some videos and tutorials online for 
# building the code, and referenced some books and online guides for syntax purposes.

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stat

# Importing the dataset from a csv and using a dataframe
iris_data = pd.read_csv(r'C:\Users\chris\Desktop\Working_Datasets\Iris.csv')
df_iris = DataFrame(iris_data)
print(iris_data)
df_iris.head(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Checking the size of the dataset
df_iris.shape
# Out:
# (150, 6)

# %%
# Checking the column names and datatypes
df_iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Ramdonly sample 10 rows of the dataset
df_iris.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 46    47            5.1           3.8            1.6           0.2
# 42    43            4.4           3.2            1.3           0.2
# 80    81            5.5           2.4            3.8           1.1
# 138  139            6.0           3.0            4.8           1.8
# 12    13            4.8           3.0            1.4           0.1
# 64    65            5.6           2.9            3.6           1.3
# 1      2            4.9           3.0            1.4           0.2
# 28    29            5.2           3.4            1.4           0.2
# 65    66            6.7           3.1            4.4           1.4
# 119  120            6.0           2.2            5.0           1.5
#
#              Species
# 46       Iris-setosa
# 42       Iris-setosa
# 80   Iris-versicolor
# 138   Iris-virginica
# 12       Iris-setosa
# 64   Iris-versicolor
# 1        Iris-setosa
# 28       Iris-setosa
# 65   Iris-versicolor
# ...

# %%
# Check only rows 47 through 57
print(df_iris[47:57])
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 47  48            4.6           3.2            1.4           0.2
# 48  49            5.3           3.7            1.5           0.2
# 49  50            5.0           3.3            1.4           0.2
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
# 55  56            5.7           2.8            4.5           1.3
# 56  57            6.3           3.3            4.7           1.6
#
#             Species
# 47      Iris-setosa
# 48      Iris-setosa
# 49      Iris-setosa
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor

# %%
# Only show the Iris species column
print(df_iris[["Species"]])
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
# Checking the values in row 78
df_iris.iloc[78]
# Out:
# Id                            79
# SepalLengthCm                  6
# SepalWidthCm                 2.9
# PetalLengthCm                4.5
# PetalWidthCm                 1.5
# Species          Iris-versicolor
# Name: 78, dtype: object

# %%
# Count the instances of values in Sepal Length
df_iris["SepalLengthCm"].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.5     7
# 5.8     7
# 6.4     7
# 6.0     6
# 4.9     6
# 6.1     6
# 5.4     6
# 5.6     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 5.2     4
# 6.2     4
# 4.6     4
# 7.2     3
# 6.8     3
# 4.4     3
# 5.9     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 4.3     1
# 7.9     1
# 7.3     1
# 7.0     1
# 4.5     1
# 5.3     1
# 7.1     1
# Name: SepalLengthCm, dtype: int64

# %%
# Count the number of instances in Sepal Width
df_iris["SepalWidthCm"].value_counts()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.8     6
# 3.3     6
# 2.6     5
# 2.3     4
# 3.6     3
# 2.4     3
# 2.2     3
# 3.7     3
# 3.9     2
# 4.2     1
# 4.1     1
# 4.4     1
# 2.0     1
# 4.0     1
# Name: SepalWidthCm, dtype: int64

# %%
# Count the number of instances in Petal Length
df_iris["PetalLengthCm"].value_counts()
# Out:
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.0     5
# 4.9     5
# 4.7     5
# 4.8     4
# 1.7     4
# 4.4     4
# 4.2     4
# 5.0     4
# 4.1     3
# 5.5     3
# 4.6     3
# 6.1     3
# 5.7     3
# 3.9     3
# 5.8     3
# 1.2     2
# 1.9     2
# 6.7     2
# 3.5     2
# 5.9     2
# 6.0     2
# 5.4     2
# 5.3     2
# 3.3     2
# 4.3     2
# 5.2     2
# 6.3     1
# 1.1     1
# 6.4     1
# 3.6     1
# 3.7     1
# 3.0     1
# 3.8     1
# 6.6     1
# 6.9     1
# 1.0     1
# Name: PetalLengthCm, dtype: int64

# %%
# Count the number of instances in Petal Width
df_iris["PetalWidthCm"].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.5    12
# 1.8    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.3     7
# 0.4     7
# 0.1     6
# 2.0     6
# 2.1     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: PetalWidthCm, dtype: int64

# %%
# Calculating the sum, mean, median, min, and max values of Sepal Length, Sepal Width, Petal Length, and Petal Width

sum_data_SLCm = df_iris["SepalLengthCm"].sum()
mean_data_SLCm = df_iris["SepalLengthCm"].mean()
median_data_SLCm = df_iris["SepalLengthCm"].median()
min_data_SLCm = df_iris["SepalLengthCm"].min()
max_data_SLCm = df_iris["SepalLengthCm"].max()

print("Values for Sepal Length in Cm")
print("Sum: ", sum_data_SLCm, "\nMean: ", mean_data_SLCm, "\nMedian: ", median_data_SLCm,
      "\nMinimum: ", min_data_SLCm, "\nMaximum: ", max_data_SLCm)

sum_data_SWCm = df_iris["SepalWidthCm"].sum()
mean_data_SWCm = df_iris["SepalWidthCm"].mean()
median_data_SWCm = df_iris["SepalWidthCm"].median()
min_data_SWCm = df_iris["SepalWidthCm"].min()
max_data_SWCm = df_iris["SepalWidthCm"].max()


print("\nValues for Sepal Width in Cm")
print("Sum: ", sum_data_SWCm, "\nMean: ", mean_data_SWCm, "\nMedian: ", median_data_SWCm,
      "\nMinimum: ", min_data_SWCm, "\nMaximum: ", max_data_SWCm)

sum_data_PLCm = df_iris["PetalLengthCm"].sum()
mean_data_PLCm = df_iris["PetalLengthCm"].mean()
median_data_PLCm = df_iris["PetalLengthCm"].median()
min_data_PLCm = df_iris["PetalLengthCm"].min()
max_data_PLCm = df_iris["PetalLengthCm"].max()


print("\nValues for Petal Length in Cm")
print("Sum: ", sum_data_PLCm, "\nMean: ", mean_data_PLCm, "\nMedian: ", median_data_PLCm,
      "\nMinimum: ", min_data_PLCm, "\nMaximum: ", max_data_PLCm)

sum_data_PWCm = df_iris["PetalWidthCm"].sum()
mean_data_PWCm = df_iris["PetalWidthCm"].mean()
median_data_PWCm = df_iris["PetalWidthCm"].median()
min_data_PWCm = df_iris["PetalWidthCm"].min()
max_data_PWCm = df_iris["PetalWidthCm"].max()


print("\nValues for Petal Width in Cm")
print("Sum: ", sum_data_PWCm, "\nMean: ", mean_data_PWCm, "\nMedian: ", median_data_PWCm,
      "\nMinimum: ", min_data_PWCm, "\nMaximum: ", max_data_PWCm)
# Out:
# Values for Sepal Length in Cm
# Sum:  876.5
# Mean:  5.843333333333335
# Median:  5.8
# Minimum:  4.3
# Maximum:  7.9
#
# Values for Sepal Width in Cm
# Sum:  458.1
# Mean:  3.0540000000000007
# Median:  3.0
# Minimum:  2.0
# Maximum:  4.4
#
# Values for Petal Length in Cm
# Sum:  563.8
# Mean:  3.7586666666666693
# Median:  4.35
# Minimum:  1.0
# Maximum:  6.9
#
# Values for Petal Width in Cm
# Sum:  179.8
# Mean:  1.1986666666666672
# Median:  1.3
# Minimum:  0.1
# Maximum:  2.5

# %%
# Checking for null values in the dataset
df_iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
# Renaming the Id column into ID
newcols = { "Id":"ID"}
df_iris.rename(columns = newcols, inplace = True) 
print(df_iris.head(10))
# Out:
#    ID  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# Style the data
df_iris.style
# Out:
# <style  type="text/css" >
# </style><table id="T_0e780b0b_5f2f_11eb_856d_985fd3d54bef" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >SepalLengthCm</th>        <th class="col_heading level0 col2" >SepalWidthCm</th>        <th class="col_heading level0 col3" >PetalLengthCm</th>        <th class="col_heading level0 col4" >PetalWidthCm</th>        <th class="col_heading level0 col5" >Species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e780b0b_5f2f_11eb_856d_985fd3d54beflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0e780b0b_5f2f_11eb_856d_985fd3d54befrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0e780b0b_5f2f_11eb_856d_985fd3d54befrow0_col1" class="data row0 col1" >5.100000</td>
# ...

# %%
# Finding the max values column wise
df_iris.head(10).style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_0e965255_5f2f_11eb_b226_985fd3d54befrow5_col1,#T_0e965255_5f2f_11eb_b226_985fd3d54befrow5_col2,#T_0e965255_5f2f_11eb_b226_985fd3d54befrow5_col3,#T_0e965255_5f2f_11eb_b226_985fd3d54befrow5_col4,#T_0e965255_5f2f_11eb_b226_985fd3d54befrow9_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_0e965255_5f2f_11eb_b226_985fd3d54bef" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >SepalLengthCm</th>        <th class="col_heading level0 col2" >SepalWidthCm</th>        <th class="col_heading level0 col3" >PetalLengthCm</th>        <th class="col_heading level0 col4" >PetalWidthCm</th>        <th class="col_heading level0 col5" >Species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e965255_5f2f_11eb_b226_985fd3d54beflevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Finding the max values row wise
df_iris.head(10).style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow0_col1,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow1_col1,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow2_col1,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow3_col1,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow4_col0,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow4_col1,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow5_col0,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow6_col0,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow7_col0,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow8_col0,#T_0e9d2b2b_5f2f_11eb_873e_985fd3d54befrow9_col0{
#             background-color:  lightgreen;
# ...

# %%
# Finding max value overall
df_iris.head(10).style.highlight_max(color = 'lightgreen', axis = None)
# Out:
# <style  type="text/css" >
# #T_0ea2f37c_5f2f_11eb_a5c4_985fd3d54befrow9_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_0ea2f37c_5f2f_11eb_a5c4_985fd3d54bef" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID</th>        <th class="col_heading level0 col1" >SepalLengthCm</th>        <th class="col_heading level0 col2" >SepalWidthCm</th>        <th class="col_heading level0 col3" >PetalLengthCm</th>        <th class="col_heading level0 col4" >PetalWidthCm</th>        <th class="col_heading level0 col5" >Species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ea2f37c_5f2f_11eb_a5c4_985fd3d54beflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ea2f37c_5f2f_11eb_a5c4_985fd3d54befrow0_col0" class="data row0 col0" >1</td>
# ...

# %%
# Machine Learning aspect
# Importing machine learning functions from sklearn

from sklearn import datasets, preprocessing

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
# Ignore ID column
iris_data_1 = iris_data.drop(['ID'], axis = 1)
df_iris_1 = DataFrame(iris_data_1)
print(iris_data_1)
print(df_iris_1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
# Summary of dataset statistics
iris_data_1_des = iris_data_1.describe()
print(iris_data_1_des)
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Univariate plotting
iris_data_1.plot(kind = 'box', subplots = True, layout = (2,2), sharex = False, sharey = False)
plt.show()

# %%
# Histogram plotting
iris_data_1.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatterplot practice from pandas
from pandas.plotting import scatter_matrix
scatter_matrix(iris_data_1)
plt.show()

# %%
plt.figure(figsize = (4,4))
sns.heatmap(iris_data_1.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
# Setting up an array for the iris data
iris_array = iris_data_1.values
print(iris_array)
# Out:
# [[5.1 3.5 1.4 0.2 'Iris-setosa']
#  [4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 0.2 'Iris-setosa']
#  [5.0 3.6 1.4 0.2 'Iris-setosa']
#  [5.4 3.9 1.7 0.4 'Iris-setosa']
#  [4.6 3.4 1.4 0.3 'Iris-setosa']
#  [5.0 3.4 1.5 0.2 'Iris-setosa']
#  [4.4 2.9 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.4 3.7 1.5 0.2 'Iris-setosa']
#  [4.8 3.4 1.6 0.2 'Iris-setosa']
#  [4.8 3.0 1.4 0.1 'Iris-setosa']
#  [4.3 3.0 1.1 0.1 'Iris-setosa']
#  [5.8 4.0 1.2 0.2 'Iris-setosa']
#  [5.7 4.4 1.5 0.4 'Iris-setosa']
#  [5.4 3.9 1.3 0.4 'Iris-setosa']
#  [5.1 3.5 1.4 0.3 'Iris-setosa']
#  [5.7 3.8 1.7 0.3 'Iris-setosa']
#  [5.1 3.8 1.5 0.3 'Iris-setosa']
#  [5.4 3.4 1.7 0.2 'Iris-setosa']
#  [5.1 3.7 1.5 0.4 'Iris-setosa']
#  [4.6 3.6 1.0 0.2 'Iris-setosa']
#  [5.1 3.3 1.7 0.5 'Iris-setosa']
#  [4.8 3.4 1.9 0.2 'Iris-setosa']
#  [5.0 3.0 1.6 0.2 'Iris-setosa']
#  [5.0 3.4 1.6 0.4 'Iris-setosa']
#  [5.2 3.5 1.5 0.2 'Iris-setosa']
# ...

# %%
# Splitting test and validation sets
X = iris_array[:,0:4]
y = iris_array[:,4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size = .2, 
                                                                random_state = 1)

# %%
# Spot Check algorithms
models = []
models.append(('LR', LogisticRegression(solver = 'liblinear', multi_class = 'ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma = 'auto')))

print(models)
# Out:
# [('LR', LogisticRegression(multi_class='ovr', solver='liblinear')), ('LDA', LinearDiscriminantAnalysis()), ('KNN', KNeighborsClassifier()), ('CART', DecisionTreeClassifier()), ('NB', GaussianNB()), ('SVM', SVC(gamma='auto'))]

# %%
# Evaluate each model
results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits = 10, random_state = 1, shuffle = True)
    cv_results = cross_val_score(model, X_train, Y_train, cv = kfold, scoring = 'accuracy')
    results.append(cv_results)
    names.append(name)
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
print(results)
# Out:
# LR: 0.941667 (0.065085)
# LDA: 0.975000 (0.038188)
# KNN: 0.958333 (0.041667)
# CART: 0.950000 (0.040825)
# NB: 0.950000 (0.055277)
# SVM: 0.983333 (0.033333)
# [array([1.        , 1.        , 1.        , 1.        , 0.83333333,
#        0.91666667, 0.83333333, 1.        , 0.91666667, 0.91666667]), array([1.        , 1.        , 1.        , 0.91666667, 0.91666667,
#        1.        , 1.        , 1.        , 0.91666667, 1.        ]), array([1.        , 0.91666667, 1.        , 0.91666667, 0.91666667,
#        0.91666667, 1.        , 1.        , 0.91666667, 1.        ]), array([1.        , 0.91666667, 1.        , 1.        , 0.91666667,
#        0.91666667, 1.        , 0.91666667, 0.91666667, 0.91666667]), array([1.        , 0.91666667, 1.        , 0.91666667, 0.91666667,
#        0.91666667, 1.        , 1.        , 0.83333333, 1.        ]), array([1.        , 1.        , 1.        , 1.        , 0.91666667,
#        1.        , 1.        , 1.        , 0.91666667, 1.        ])]

# %%
# Visualizing algorithm comparison
plt.boxplot(results, labels = names)
plt.title('Algorithm Comparison')
plt.show()

# %%
# Create and validate predictions
# From algorithm comparison, SVM (Support Vector Machines) performed the best, 
# so this will be used for the final model
model = SVC(gamma = 'auto')
model.fit(X_train, Y_train)
prediction = model.predict(X_validation)

print(accuracy_score(Y_validation, prediction))
print(confusion_matrix(Y_validation, prediction))
print(classification_report(Y_validation, prediction))

iris_confusion_matrix = confusion_matrix(Y_validation, prediction)
sns.heatmap(iris_confusion_matrix, cmap = 'Blues', annot = True)
# Out:
# 0.9666666666666667
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
# <AxesSubplot:>
